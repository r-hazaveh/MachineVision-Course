# %%
# !pip install opencv-python-headless

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path = "/content/drive/MyDrive/Colab Notebooks/class.vision-master/images"
img = cv2.imread(f'{data_path}/input.jpg')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cv2_imshow(img)
cv2.waitKey(0)  # montazere yek kelid mimanad
cv2.destroyAllWindows()  # tamame panjereha ra mibandad.
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>

# %%
print(type(img))
print(img.shape)
print('The Heihght : ', int(img.shape[0]))
# Out:
# <class 'numpy.ndarray'>
# (600, 800, 3)
# The Heihght :  600

# %%
cv2.imwrite(f'{data_path}/Test-Image/input_tst1.jpg',img)
cv2.imwrite(f'{data_path}/Test-Image/input_tst1.png',img)
# Out:
# True

# %%
import matplotlib.pyplot as plt  # matplotlib ba RGB kar mikonad va CV2 ba BGR
plt.imshow(img[:,:,::-1])
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)

# %%
img[200:300,300:500,:] = (0,255,255)
plt.imshow(img[:,:,::-1])

# %%
img[200:300,300:500,:] = (0,100,150)
plt.imshow(img[...,::-1])  # ...  yani har chand ta boad

# %%
img[200:300,300:500,:] = (0,255,0)
plt.imshow(img[...,::-1])  # ...  yani har chand ta boad
