# %% [markdown]
# ## <div style="direction:rtl;text-align:right;font-family:B Lotus, B Nazanin, Tahoma">کانال آلفا و تصاویر 4 کاناله</div>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
data_path = "/content/drive/MyDrive/Colab Notebooks/class.vision-master/images"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Example to read PNG image containing four channels (Red, Green, Blue, Alpha).

# %%
img = cv2.imread(f'{data_path}/transparency.png', cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (600, 800, 4)

# %%
bgr_image = img[...,0:3]
alpha_image = img[...,-1]
rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image); plt.title("RGB");

# %%
plt.imshow(alpha_image, cmap='gray'); plt.title("Alpha");

# %% [markdown]
# Try with another image

# %%
img = cv2.imread(f'{data_path}/alpha.png', cv2.IMREAD_UNCHANGED)
img.shape
# Out:
# (704, 1000, 4)

# %%
bgr_image = img[...,0:3]
alpha_image = img[...,-1]
rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image); plt.title("RGB");

# %%
plt.imshow(alpha_image, cmap='gray'); plt.title("Alpha");

# %% [markdown]
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# مقدار $\alpha$ مقداری بین 0 تا 255 است که تقسیم بر 255 خواهد شد و فرمول زیر را خواهیم داشت:
# <br/>
# پس خواهیم داشت: $0 \leq \alpha \leq 1$</div>
#
# $I = \alpha F + (1 - \alpha) B$
#
# <div style="direction:rtl;text-align:right;font-family:Tahoma">
# طبق فرمول بالا
#     <br/>
#
#  - وقتی $\alpha = 0$, خروجی تصویر پس زمینه است.
#  - وقتی $\alpha = 1$, خروجی تصویر شما یا زمینه است
#  - وقتی $0 < \alpha < 1$
#     یک ترکیب از تصویر و تصویر پس زمینه است
# </div>

# %% [markdown]
# PNG image from [Alpha matting evaluation website](http://www.alphamatting.com/datasets.php)
